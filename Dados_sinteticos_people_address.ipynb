# %%
pip install faker
# Out:
# Collecting faker
#   Downloading Faker-36.1.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.11/dist-packages (from faker) (2025.1)
# Downloading Faker-36.1.1-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 21.4 MB/s eta 0:00:00
# Installing collected packages: faker
# Successfully installed faker-36.1.1

# %%
import csv
from faker import Faker

# Gerar dados aleatórios
fake = Faker()
data = [(i + 1, fake.first_name(), fake.last_name()) for i in range(1000000)]

# Criar e escrever no arquivo CSV
csv_filename = "people.csv"
with open(csv_filename, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["PersonId", "FirstName", "LastName"])  # Cabeçalho
    writer.writerows(data)

print(f"Arquivo CSV '{csv_filename}' criado com 1.000.000 registros!")
# Out:
# Arquivo CSV 'people.csv' criado com 1.000.000 registros!

# %% [markdown]
# ![table_person.jpg](data:image/jpeg;base64,...)

# %%
import csv
from faker import Faker

# Gerar dados aleatórios
fake = Faker()
data = [(i+200, i + 1, fake.city(), fake.state()) for i in range(1000000)]

# Criar e escrever no arquivo CSV
csv_filename = "address.csv"
with open(csv_filename, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["AddressId", "PersonId", "City", "Address"])  # Cabeçalho
    writer.writerows(data)

print(f"Arquivo CSV '{csv_filename}' criado com 1.000.000 registros!")
# Out:
# Arquivo CSV 'address.csv' criado com 1.000.000 registros!

# %% [markdown]
# ![table_address.jpg](data:image/jpeg;base64,...)
